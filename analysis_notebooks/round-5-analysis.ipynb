# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

price_data = pd.read_csv('../data/round5/prices_combined.csv', header=0, sep=';')

# %%
pepper_data = price_data[price_data['product'] == 'MICROCHIP_OVAL']
pepper_prices = pepper_data['mid_price'].replace(0, np.nan).ffill()

diffed = pepper_prices.diff(1)
plt.plot(pepper_data['timestamp'], pepper_prices)
